# %% [markdown]
# ## Pide portatil

# %%
import numpy as np

# %%
with open('8anverso_1.txt') as f:
    lines = f.readlines()
for line in lines:
    if line.__contains__("SC ="):  
        print(line)
        newstr = ''.join((ch if ch in '0123456789.-e' else ' ') for ch in line)
        listOfNumbers = [float(i) for i in newstr.split()]
        print(listOfNumbers)
# Out:
#            SC =            6.030           6.000           0.030           0.100          -0.100              OK
#
# [6.03, 6.0, 0.03, 0.1, -0.1]
#            SC =            6.081           6.000           0.081           0.100          -0.100              OK
#
# [6.081, 6.0, 0.081, 0.1, -0.1]
#            SC =            1.305           1.500          -0.195           0.100          -0.100           NO OK
#
# [1.305, 1.5, -0.195, 0.1, -0.1]
#            SC =            6.029           6.000           0.029           0.100          -0.100              OK
#
# [6.029, 6.0, 0.029, 0.1, -0.1]
#            SC =            6.085           6.000           0.085           0.100          -0.100              OK
#
# [6.085, 6.0, 0.085, 0.1, -0.1]
#            SC =            1.336           1.500          -0.164           0.100          -0.100           NO OK
#
# [1.336, 1.5, -0.164, 0.1, -0.1]
# ...
